thank… https://t.co/cbCUkTRWPE), (986031318713683969, 2018-04-16 23:59:20, Thank you to everyone who voted for us in the Shorty Awards and to anyone who has ever liked a dog rate. This incre… https://t.co/su8yZvwQCm), (985925506536235008, 2018-04-16 16:58:53, @agirlkenndream_ no), (985700162956865536, 2018-04-16 02:03:26, RT @shortyawards: Wow, so honored to get to tweet this: @dog_rates doing very good work, much enthusiasm, 13/10. Congrats on your Best Anim…), (985592491792625666, 2018-04-15 18:55:36, free him https://t.co/zI1h2Q6RIO), (985375275281207296, 2018-04-15 04:32:27, @Dodgers dogdgers :)), (985227249023684608, 2018-04-14 18:44:15, @JeffVeillette ❤️), (985197159451512832, 2018-04-14 16:44:41, This is Stella. She has been crowned the dandelion queen. Has waited her whole life for such a h*ckin honor. 13/10… https://t.co/oMfQQDpV1y), (985012722675978240, 2018-04-14 04:31:48, @AndyManganelli I’m here this weekend!), (984978760968671232, 2018-04-14 02:16:51, @youkneeskyna @CaseyNeistat @blacktapnyc ...h*ck), (984977443814559744, 2018-04-14 02:11:37, @CaseyNeistat @blacktapnyc having it for the first time right now (yes i already ate some so the pic isn’t as prett… https://t.co/NqsdnwP27r), (984899768471248896, 2018-04-13 21:02:58, This is Percy. A few weeks ago he started having trouble eating, which was very concerning because food is like his… https://t.co/9SGca1NSIC), (984594512780709888, 2018-04-13 00:49:59, This is Kipling. He noticed you forgot a towel for after your shower. Thought he could be of assistance. 14/10 a tr… https://t.co/TYVt8DB4dv), (984428686752538625, 2018-04-12 13:51:03, @Ms_Cooper_ ❤️), (984230513396285441, 2018-04-12 00:43:35, This is Brutus. He found a twig and got emotionally attached to it. Hoping you’ll let him bring it inside for event… https://t.co/BAorciwNPo), (984170643120906241, 2018-04-11 20:45:40, @Maxqz_ @ChrisEvans let’s not watch it from an account that doesn’t credit the original), (984169992051679233, 2018-04-11 20:43:05, RT @ChrisEvans: This is the moment we met. He was trying so hard to stay seated even though he desperately wanted to get out. I knew right…), (983850009203544065, 2018-04-10 23:31:35, This  ...
#
# [11715 rows x 0 columns]

# %%
data_scores = data[data['text'].str.contains('([0-9]/10)')==True]
data_scores['score'] = data['text'].str.extract(r'([0-9]/10)')
data_scores = data_scores.dropna(subset=['score'])    # Remove entries with NaN
data_scores['score'] = data_scores['score'].apply(pd.eval)
data_scores = data_scores.sort_values(by=['score'])
# Out:
# /var/folders/hv/gvfqssds0sb3s3n6whxvjszw0000gn/T/ipykernel_11198/341766220.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   data_scores = data[data['text'].str.contains('([0-9]/10)')==True]
# /var/folders/hv/gvfqssds0sb3s3n6whxvjszw0000gn/T/ipykernel_11198/341766220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_scores['score'] = data['text'].str.extract(r'([0-9]/10)')

# %%
data_scores['created_at'] = pd.to_datetime(data_scores['created_at'])
data_scores['timestamp'] = data_scores['created_at'].values.astype(np.timedelta64) / np.timedelta64(1, 'ms')

# %%
x = data_scores['created_at']
x_ts = data_scores['timestamp']
y = data_scores['score']

res = linregress(x_ts, y)
data_scores['prediction'] = (res.intercept + res.slope*x_ts)

# %%
data_scores
# Out:
#                       id          created_at  \
# 5028  746790600704425984 2016-06-25 19:42:08
# 5680  706593038911545345 2016-03-06 21:31:22
# 3590  826615380357632002 2017-02-01 02:17:19
# 5289  724046343203856385 2016-04-24 01:24:35
# 4852  757393109802180609 2016-07-25 01:52:43
# ...                  ...                 ...
# 5257  727286334147182592 2016-05-02 23:59:09
# 4839  758041019896193024 2016-07-26 20:47:17
# 5611  709519240576036864 2016-03-14 23:19:03
# 5108  740711788199743490 2016-06-09 01:07:06
# 5053  744995568523612160 2016-06-20 20:49:19
#
#                                                    text  score     timestamp  \
# 5028  When you just can't resist... 10/10 topnotch t...    0.0  1.466884e+12
# 5680  Here's a sneak peek of me on spring break. 10/...    0.0  1.457300e+12
# 3590  RT @dog_rates: Please only send in dogs. We on...    0.0  1.485915e+12
# 5289  This is Sarge. Not even he knows what his tong...    0.0  1.461461e+12
# 4852  Here's a doggo completely oblivious to the dou...    0.0  1.469412e+12
# ...                                                 ...    ...           ...
# 5257  I swear to god if we get sent another Blue Mad...    0.9  1.462234e+12
# 4839  Teagan reads entire books in store so they're ...    0.9  1.469566e+12
# 5611  This is Vince. He's a Gregorian Flapjeck. Whit...    0.9  1.457998e+12
# 5108  Here we are witnessing the touchdown of a pupn...    0.9  1.465434e+12
# 5053  This is Abby. She got her face stuck in a glas...    0.9  1.466456e+12
#
#       prediction
# 5028    0.210937
# 5680    0.200367
# 3590    0.231928
# 5289    0.204956
# 4852    0.213725
# ...          ...
# 5257    0.205808
# 4839    0.213896
# 5611    0.201136
# 5108    0.209339
# 5053    0.210465
#
# [1877 rows x 6 columns]

# %%
res.slope, res.intercept
# Out:
# (1.1029587796244462e-12, -1.4069750670241357)

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=25)
plt.scatter(x, y, label='data', alpha=0.5)
plt.plot(x, res.intercept + res.slope*x_ts, 'r', linewidth=3, label='fitted line')
plt.title("Pup Inflation")
plt.ylabel("Scores")
plt.xlabel("Date Created")
plt.legend()
plt.show()

# %% [markdown]
# "Have the ratings given by this Twitter account been changing over time?"
# - Output the p-value from the regression
# - Question: "is the slope different from zero?"
# - Plot Hist. residuals: observed vals - predicted vals

# %%
mean_score = np.mean(data_scores['score'])
std_score = np.std(data_scores['score'])
mean_score, std_score
# Out:
# (0.24208843899840177, 0.16761674152668737)

# %%
res.pvalue
# Out:
# 2.9427105540525786e-25

# %%
data_scores['predict'] = res.slope*data_scores['timestamp'] + res.intercept
data_scores['residual'] = data_scores['score'] - data_scores['predict']

# %%
plt.figure(figsize=(8,5))
plt.hist(data_scores['residual'])
plt.title("Residuals of Pup Inflation")
plt.xlabel("Residual")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
